# %%
import pandas as pd
import time

# Read in the Parquet file
df = pd.read_parquet("1-special.parquet")
df2 = pd.read_parquet("/home/dcai/data/EURUSD/2022/1.parquet")

# Display the top 10 rows
print(df.head(10))
print(df.dtypes)
print(df2.dtypes)

start_time = time.time()
df['DateTime'] = pd.to_datetime(df['DateTime'])
end_time = time.time()

elapsed_time = end_time - start_time
print(f'Execution time: {elapsed_time:.3f} seconds')
# Out:
#                   DateTime      Bid      Ask
# 0  01/02/2022 22:01:11.650  1.03611  1.03779
# 1  01/02/2022 22:03:14.326  1.03659  1.03729
# 2  01/02/2022 22:03:14.352   1.0366   1.0373
# 3  01/02/2022 22:03:15.152  1.03658  1.03728
# 4  01/02/2022 22:03:16.252   1.0366   1.0373
# 5  01/02/2022 22:03:48.482  1.03659  1.03729
# 6  01/02/2022 22:04:17.338  1.03606  1.03781
# 7  01/02/2022 22:04:46.160  1.03611  1.03779
# 8  01/02/2022 22:05:03.653  1.03659  1.03729
# 9  01/02/2022 22:06:05.259  1.03658  1.03728
# DateTime    object
# Bid         object
# Ask         object
# dtype: object
# DateTime    datetime64[ns]
# Bid                 object
# Ask                 object
# dtype: object
# Execution time: 38.410 seconds
